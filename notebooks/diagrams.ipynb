# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define the mesh grid
x = np.linspace(-7,3, 50)
y = np.linspace(-3, 7, 50)
x, y = np.meshgrid(x, y)
z = (x+2)**2 + (y-1)**2  # Parabolic function

# Apply a transformation to change the principal axes
R = np.array([[.5, -0.8, 0], [0.5, 0.8, 0], [0, 0, 1]])  # Rotation matrix
coords = np.vstack([x.flatten(), y.flatten(), z.flatten()])
transformed_coords = R @ coords
x_t = transformed_coords[0].reshape(x.shape)
y_t = transformed_coords[1].reshape(y.shape)
z_t = transformed_coords[2].reshape(z.shape)

# Create the 3D figure
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface mesh with transformed coordinates
ax.plot_surface(x_t, y_t, z_t, cmap='viridis_r', edgecolor='none', alpha=1)

# Don't show grid lines on the surface plot, but show them on the axes


# Labels
# Set z label as Z
ax.set_xlabel('$\phi_1$')
ax.set_ylabel('$\phi_2$')
ax.set_zlabel('L', labelpad=0)
ax.zaxis.label.set_size(12)
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)

# Remove tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])
ax.legend()
ax.set_box_aspect(aspect=None, zoom=0.8)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_40603/1928417204.py:38: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
z = 0*x**2 + y**2  # Parabolic function

# Apply a transformation to change the principal axes
R = np.array([[.5, -0.8, 0], [0.5, 0.8, 0], [0, 0, 1]])  # Rotation matrix
coords = np.vstack([x.flatten(), y.flatten(), z.flatten()])
transformed_coords = R @ coords
x_t = transformed_coords[0].reshape(x.shape)
y_t = transformed_coords[1].reshape(y.shape)
z_t = transformed_coords[2].reshape(z.shape)

# Create the 3D figure
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface mesh with transformed coordinates
ax.plot_surface(x_t, y_t, z_t, cmap='viridis_r', edgecolor='none', alpha=1)

# Don't show grid lines on the surface plot, but show them on the axes


# Labels
# Set z label as Z
ax.set_xlabel('$\phi_1$')
ax.set_ylabel('$\phi_2$')
ax.set_zlabel('L', labelpad=0)
ax.zaxis.label.set_size(12)


# Remove tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])
ax.legend()
ax.set_box_aspect(aspect=None, zoom=0.8)

# Show the plot

plt.show()

# Interploate all the way through the figure
plt.contour(x_t, y_t, z_t, cmap='viridis_r', levels=50)

plt.show()
# Out:
# /tmp/ipykernel_40603/2190698202.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
x_t
# Out:
# array([[ 0.6       ,  0.64591837,  0.69183673, ...,  2.75816327,
#          2.80408163,  2.85      ],
#        [ 0.52653061,  0.57244898,  0.61836735, ...,  2.68469388,
#          2.73061224,  2.77653061],
#        [ 0.45306122,  0.49897959,  0.54489796, ...,  2.61122449,
#          2.65714286,  2.70306122],
#        ...,
#        [-2.85306122, -2.80714286, -2.76122449, ..., -0.69489796,
#         -0.64897959, -0.60306122],
#        [-2.92653061, -2.88061224, -2.83469388, ..., -0.76836735,
#         -0.72244898, -0.67653061],
#        [-3.        , -2.95408163, -2.90816327, ..., -0.84183673,
#         -0.79591837, -0.75      ]])

# %%
x = np.linspace(-2, 2.5, 50)
y = np.linspace(-2, 2.5, 50)

def f(x,y):
    return (x-1)*(x-2)*(x-2)*(x+2) + x*(y-1)**2 + (y-1.5)*(y-1.5)*(y+.5)*(y+1)
x = np.linspace(-2, 2.5, 50)

plt.plot(x, f(x,0))
# Plot contour
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

x, y = np.meshgrid(x, y)
z = f(x,y)

ax.contour(x, y,z, cmap='viridis_r', levels=50)
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis_r', edgecolor='none', alpha=1)
plt.show()


fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.contour(2*y, -x,z, cmap='viridis_r', levels=50)
plt.show()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis_r', edgecolor='none', alpha=1)
plt.show()

# %%
# Make z a cubic funciton of x and y
x = np.linspace(-3, 5, 50)
y = np.linspace(-3, 5, 50)
x, y = np.meshgrid(x, y)
z =  (x-2)**2+(y-2)**2 


import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Create the 3D figure
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

# Plot the surface mesh with transformed coordinates
ax.contour(x, y, z, cmap='viridis_r', levels=50)

# Don't show grid lines on the surface plot, but show them on the axes


# Labels
# Set z label as Z
ax.set_xlabel('$\phi_1$')
ax.set_ylabel('$\phi_2$')


# Remove tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.legend()
ax.set_box_aspect(aspect=None)

# Show the plot

plt.show()
# Out:
# /tmp/ipykernel_40603/555555901.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the mesh grid
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
z = x**2 + 0*y**2  # Parabolic function

# Apply a transformation to change the principal axes
R = np.array([[.5, -0.8, 0], [0.5, 0.8, 0], [0, 0, 1]])  # Rotation matrix
coords = np.vstack([x.flatten(), y.flatten(), z.flatten()])
transformed_coords = R @ coords
x_t = transformed_coords[0].reshape(x.shape)
y_t = transformed_coords[1].reshape(y.shape)
z_t = transformed_coords[2].reshape(z.shape)

# Create the 3D figure
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface mesh with transformed coordinates
ax.plot_surface(x_t, y_t, z_t, cmap='viridis_r', edgecolor='none', alpha=1)

# Don't show grid lines on the surface plot, but show them on the axes


# Labels
# Set z label as Z
ax.set_xlabel('$\phi_1$')
ax.set_ylabel('$\phi_2$')
ax.set_zlabel('L', labelpad=0)
ax.zaxis.label.set_size(12)


# Remove tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])
ax.legend()
ax.set_box_aspect(aspect=None, zoom=0.8)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_41006/3981787361.py:41: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
